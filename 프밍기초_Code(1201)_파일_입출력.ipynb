# %% [markdown]
# <a href="https://colab.research.google.com/github/junsikcho/Programming-Basics/blob/main/%ED%94%84%EB%B0%8D%EA%B8%B0%EC%B4%88_Code(1201)_%ED%8C%8C%EC%9D%BC_%EC%9E%85%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 12장 -01 파일 입출력

# %% [markdown]
# - 파일 입출력의 개념과 기본 작업(열기, 읽기, 쓰기, 닫기)을 설명할 수 있다.
# - 파일 입출력을 사용하여 데이터를 저장하거나 불러오는 프로그램을 작성할 수 있다.

# %% [markdown]
# # [프로그램 파일의 내용을 암호화하거나 암호화된 파일을 다시 해독하는 프로그램 만들기

# %% [markdown]
# - 파일 입출력의 기본 단계\
# 1) 파일 열기\
# 2) 파일 읽기 및 파일 쓰기 작업\
# 3) 파일 닫기

# %% [markdown]
# ![화면 캡처 2024-12-03 232139.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2024-12-03 232231.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2024-12-03 232252.png](data:image/png;base64,...)
